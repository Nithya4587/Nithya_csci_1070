# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

credit_df = pd.read_csv('Credit_card.csv')
credit_df.head()
# Out:
#     Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0  5008827      M         Y             Y         0       180000.0
# 1  5009744      F         Y             N         0       315000.0
# 2  5009746      F         Y             N         0       315000.0
# 3  5009749      F         Y             N         0            NaN
# 4  5009752      F         Y             N         0       315000.0
#
#             Type_Income         EDUCATION Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
#
#    Birthday_count  Employed_days  Mobile_phone  Work_Phone  Phone  EMAIL_ID  \
# ...

# %%
X = credit_df.drop(['GENDER','Car_Owner','Propert_Owner','Type_Income','EDUCATION','Marital_status','Housing_type','Type_Occupation','Annual_income','Birthday_count'], axis = 1)
y = credit_df['CHILDREN']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3, 
                                                    random_state =32)

model = LogisticRegression(random_state=32).fit(X_train, y_train)
y_predicted = model.predict(X_test)

print(model.score(X_test,y_test))
# Out:
# 0.7096774193548387

# %%
from sklearn.decomposition import TruncatedSVD

svd = TruncatedSVD(n_components=6)

X_train_svd = svd.fit_transform(X_train)
X_test_svd = svd.fit_transform(X_test)

model = LogisticRegression(random_state=32).fit(X_train_svd, y_train)

model.score(X_test_svd, y_test)
# Out:
# 0.7096774193548387

# %% [markdown]
# Applying one dimensionality-reduction did not influence the performance of the model. The model score stayed the same even after apply SVD.
