# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_df = pd.read_csv('data.csv', encoding='unicode_escape')
data_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
data_df.dropna(subset=['Description'], inplace=True)
data_df.dropna(subset=['CustomerID'], inplace=True)
data_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# Null values are handled using dropna on different columns that have null values.

# %%
from sklearn.cluster import KMeans
X = data_df.drop('Country',axis=1)
y = data_df['Country']

plt.scatter(X['CustomerID',X['Quantity']])

for i, txt in enumerate(y):
    plt.annotate(txt, (X['CustomerID'][i],X['Quantity'][i]))
    
plt.xlabel('CustomerID')
plt.ylabel('Quantity')
plt.show
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File /usr/lib/python3/dist-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /usr/lib/python3/dist-packages/pandas/_libs/index.pyx:144, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '('CustomerID', 0          6
# 1          6
# 2          8
# 3          6
# 4          6
#           ..
# 541904    12
# 541905     6
# 541906     4
# 541907     4
# 541908     3
# Name: Quantity, Length: 406829, dtype: int64)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
#2
inertias = []
distortions = []

for k in range(1,10):
    model = KMeans(n_clusters=k).fit(X)
    distance = cdist(X, model.cluster_centers_,
                                  'euclidean')
    distortion = sum(np.min(distance,axis =1))/X.shape[0]
    distortions.append(distortion)
    inertia = model.inertia_
    inertias.append(inertia)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [30], line 6
#       3 distortions = []
#       5 for k in range(1,10):
# ----> 6     model = KMeans(n_clusters=k).fit(X)
#       7     distance = cdist(X, model.cluster_centers_,
#       8                                   'euclidean')
#       9     distortion = sum(np.min(distance,axis =1))/X.shape[0]
#
# File /usr/lib/python3/dist-packages/sklearn/cluster/_kmeans.py:1417, in KMeans.fit(self, X, y, sample_weight)
#    1390 """Compute k-means clustering.
#    1391
#    1392 Parameters
#    (...)
#    1413     Fitted estimator.
#    1414 """
#    1415 self._validate_params()
# -> 1417 X = self._validate_data(
#    1418     X,
#    1419     accept_sparse="csr",
#    1420     dtype=[np.float64, np.float32],
#    1421     order="C",
#    1422     copy=self.copy_x,
#    1423     accept_large_sparse=False,
#    1424 )
# ...
