# %%
#1
import nltk

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
paradise = nltk.corpus.gutenberg.words('milton-paradise.txt')
paradise
# Out:
# ['[', 'Paradise', 'Lost', 'by', 'John', 'Milton', ...]

# %%
text_sentences = nltk.corpus.gutenberg.sents('milton-paradise.txt')[:10]
print(text_sentences)
# Out:
# [['[', 'Paradise', 'Lost', 'by', 'John', 'Milton', '1667', ']'], ['Book', 'I'], ['Of', 'Man', "'", 's', 'first', 'disobedience', ',', 'and', 'the', 'fruit', 'Of', 'that', 'forbidden', 'tree', 'whose', 'mortal', 'taste', 'Brought', 'death', 'into', 'the', 'World', ',', 'and', 'all', 'our', 'woe', ',', 'With', 'loss', 'of', 'Eden', ',', 'till', 'one', 'greater', 'Man', 'Restore', 'us', ',', 'and', 'regain', 'the', 'blissful', 'seat', ',', 'Sing', ',', 'Heavenly', 'Muse', ',', 'that', ',', 'on', 'the', 'secret', 'top', 'Of', 'Oreb', ',', 'or', 'of', 'Sinai', ',', 'didst', 'inspire', 'That', 'shepherd', 'who', 'first', 'taught', 'the', 'chosen', 'seed', 'In', 'the', 'beginning', 'how', 'the', 'heavens', 'and', 'earth', 'Rose', 'out', 'of', 'Chaos', ':', 'or', ',', 'if', 'Sion', 'hill', 'Delight', 'thee', 'more', ',', 'and', 'Siloa', "'", 's', 'brook', 'that', 'flowed', 'Fast', 'by', 'the', 'oracle', 'of', 'God', ',', 'I', 'thence', 'Invoke', 'thy', 'aid', 'to', 'my', 'adventurous', 'song
# ...

# %%
for sentence in text_sentences:
    new_filtered_list = [word for word in sentence if word.isalnum()]

# %%
filtered_new = [word for word in new_filtered_list if word not in stopwords.words('english')]

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import itertools
import pandas as pd
from collections import Counter

my_final = filtered_new

words = list(itertools.chain(*my_final))

porter = PorterStemmer()
stemmed = [porter.stem(word) for word in words]
print(stemmed[:50])

count = Counter(stemmed)
top_words = count.most_common(20)
print("Top 20 stemmed words:", top_words)

top_words_stemmed, top_words_count = zip(*top_words)
plt.figure(figsize=(12, 6))
plt.bar(top_words_stemmed, top_words_count, color='skyblue')
plt.xlabel('Stemmed Words')
plt.ylabel('Frequency')
plt.title('Top 20 Stemmed Words in "Paradise Lost"')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ['b', 'u', 't', 'd', 'o', 'o', 'm', 'r', 'e', 's', 'e', 'r', 'v', 'e', 'd', 'w', 'r', 'a', 't', 'h', 't', 'h', 'o', 'u', 'g', 'h', 't', 'b', 'o', 't', 'h', 'l', 'o', 's', 't', 'h', 'a', 'p', 'p', 'i', 'n', 'e', 's', 's', 'l', 'a', 's', 't', 'i', 'n']
# Top 20 stemmed words: [('t', 18), ('e', 16), ('s', 13), ('a', 12), ('o', 10), ('d', 9), ('h', 9), ('i', 9), ('r', 8), ('n', 7), ('u', 6), ('l', 5), ('b', 4), ('m', 4), ('p', 4), ('f', 4), ('w', 3), ('g', 3), ('y', 2), ('v', 1)]

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import itertools
import pandas as pd
from collections import Counter

my_final = text_sentences

words = list(itertools.chain(*my_final))

porter = PorterStemmer()
stemmed = [porter.stem(word) for word in words]
print(stemmed[:50])

count = Counter(stemmed)
top_words = count.most_common(20)
print("Top 20 stemmed words:", top_words)

top_words_stemmed, top_words_count = zip(*top_words)
plt.figure(figsize=(12, 6))
plt.bar(top_words_stemmed, top_words_count, color='skyblue')
plt.xlabel('Stemmed Words')
plt.ylabel('Frequency')
plt.title('Top 20 Stemmed Words in "Paradise Lost"')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ['[', 'paradis', 'lost', 'by', 'john', 'milton', '1667', ']', 'book', 'i', 'of', 'man', "'", 's', 'first', 'disobedi', ',', 'and', 'the', 'fruit', 'of', 'that', 'forbidden', 'tree', 'whose', 'mortal', 'tast', 'brought', 'death', 'into', 'the', 'world', ',', 'and', 'all', 'our', 'woe', ',', 'with', 'loss', 'of', 'eden', ',', 'till', 'one', 'greater', 'man', 'restor', 'us', ',']
# Top 20 stemmed words: [(',', 57), ('and', 22), ('the', 21), ('of', 16), ('to', 13), ('that', 11), ("'", 10), ('with', 10), ('in', 8), ('.', 7), ('hi', 7), ('first', 6), ('heaven', 5), ('th', 5), ('from', 5), ('he', 5), ('for', 4), (';', 4), ('what', 4), ('him', 4)]

# %% [markdown]
# I chose stemming as it could find root words in a more easier and effective way.

# %%
#2
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
text = 'milton-paradise.txt'

# %%
sentiment = analyzer.polarity_scores(text)
print(sentiment)
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
sentiments = []
compound = sentiment['compound']
pos = sentiment['pos']
neg = sentiment['neg']
neu = sentiment['neu']

sentiments.append({
    "text": text,
    "compound": compound,
    "positive": pos,
    "negative": neg,
    "neutral": neu
})
sentiments
# Out:
# [{'text': 'milton-paradise.txt',
#   'compound': 0.0,
#   'positive': 0.0,
#   'negative': 0.0,
#   'neutral': 1.0}]

# %%
for sentence in text:
    sid = SentimentIntensityAnalyzer()
    print(sentence)
    ss = sid.polarity_scores(sentence)
    for k in sorted(ss):
        print('{0}: {1}, '.format(k, ss[k]), end='')
    print()
# Out:
# m
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# i
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# l
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# t
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# o
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# n
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# -
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# p
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# a
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# r
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# a
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# d
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# i
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# s
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# e
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# .
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# t
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# x
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# t
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,

# %%
analyzer = SentimentIntensityAnalyzer()
text_extract = '''The measure is English heroic verse without rhyme, as that of Homer 
in Greek, and of Vergil in Latin; rhyme being no necessary 
adjunct or true ornament of poem or good verse, in longer 
works especially, but the invention of a barbarous age, 
to set off wretched matter and lame meter; graced indeed 
since by the use of some famous modern poets, carried away 
by custom, but much to their own vexation, hindrance, and 
constraint to express many things otherwise, and for the 
most part worse than else they would have expressed them.'''

# %%
sentiment = analyzer.polarity_scores(text_extract)
print(sentiment)
# Out:
# {'neg': 0.159, 'neu': 0.753, 'pos': 0.089, 'compound': -0.8914}

# %%
sentiments = []
compound = sentiment['compound']
pos = sentiment['pos']
neg = sentiment['neg']
neu = sentiment['neu']

sentiments.append({
    "text": text_extract,
    "compound": compound,
    "positive": pos,
    "negative": neg,
    "neutral": neu
})
sentiments
# Out:
# [{'text': 'The measure is English heroic verse without rhyme, as that of Homer \nin Greek, and of Vergil in Latin; rhyme being no necessary \nadjunct or true ornament of poem or good verse, in longer \nworks especially, but the invention of a barbarous age, \nto set off wretched matter and lame meter; graced indeed \nsince by the use of some famous modern poets, carried away \nby custom, but much to their own vexation, hindrance, and \nconstraint to express many things otherwise, and for the \nmost part worse than else they would have expressed them.',
#   'compound': -0.8914,
#   'positive': 0.089,
#   'negative': 0.159,
#   'neutral': 0.753}]

# %%
sentences.extend(text_extract)
for sentence in text_extract:
    sid = SentimentIntensityAnalyzer()
    print(sentence)
    ss = sid.polarity_scores(sentence)
    for k in sorted(ss):
        print('{0}: {1}, '.format(k, ss[k]), end='')
    print()
# Out:
# T
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# h
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# e
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
#
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# m
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# e
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# a
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# s
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# u
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# r
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# e
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
#
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# i
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# s
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
#
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# E
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# n
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# g
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# l
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# i
# ...

# %% [markdown]
# 3. All the sentences seems to be equal in negative, positive, and neutral sentences. I don't think that the sentiment analysis is correct as they show that it is 0.0 for all, but isi different in the appending one.

# %%
from wordcloud import WordCloud, STOPWORDS

text = '''The measure is English heroic verse without rhyme, as that of Homer 
in Greek, and of Vergil in Latin; rhyme being no necessary 
adjunct or true ornament of poem or good verse, in longer 
works especially, but the invention of a barbarous age, 
to set off wretched matter and lame meter; graced indeed 
since by the use of some famous modern poets, carried away 
by custom, but much to their own vexation, hindrance, and 
constraint to express many things otherwise, and for the 
most part worse than else they would have expressed them.'''

wordcloud = WordCloud(stopwords=STOPWORDS, background_color='black', max_words=20).generate(text)
plt.figure(figsize=(15,10))
plt.clf()
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
